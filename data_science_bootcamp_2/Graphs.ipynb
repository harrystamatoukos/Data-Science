# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use('fivethirtyeight')

# %%
# %matplotlib inline

# %%
housing  = pd.read_csv('data/boston_housing_data.csv')

# %%
drinks_columns = ['country','beer','spirit','wine','liters','continent']
drinks = pd.read_csv('data/drinks.csv',header = 0 , names= drinks_columns)

# %%
ufo = pd.read_csv('data/ufo.csv')
ufo['Time'] = pd.to_datetime(ufo.Time)
ufo['Year'] = ufo.Time.dt.year

# %%
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 80538                Neligh             NaN         CIRCLE    NE
# 80539          Uhrichsville             NaN          LIGHT    OH
# 80540                Tucson        RED BLUE            NaN    AZ
# 80541           Orland park             RED          LIGHT    IL
# 80542              Loughman             NaN          LIGHT    FL
#
#                      Time  Year
# 0     1930-06-01 22:00:00  1930
# 1     1930-06-30 20:00:00  1930
# 2     1931-02-15 14:00:00  1931
# 3     1931-06-01 13:00:00  1931
# ...

# %%
ufo.Year.value_counts().sort_index().plot()

# %%
drinks.continent.value_counts().plot(kind = 'barh')

# %%
df = pd.DataFrame(np.random.randn(10, 4), 
                  columns=['col1', 'col2', 'col3', 'col4'],
                  index=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'])

# %%
df
# Out:
#        col1      col2      col3      col4
# a  0.215444  0.881123  1.451751  1.005738
# b -0.123932 -0.305927 -0.569135  0.678836
# c  0.395304 -0.319570  0.967717 -0.671740
# d -0.159208 -0.014225 -0.556031  1.820433
# e -0.026579  0.556132 -1.459281  1.007852
# f -1.050851 -2.672460  2.110316 -1.637012
# g -0.598758 -1.250150  1.698695  0.368853
# h  0.021274  0.009200 -2.173392  0.091578
# i  0.079719  0.040432 -0.905863 -1.210862
# j -0.064501  0.178621 -1.343861 -0.600877

# %%
df.plot(figsize = (12, 6))

# %%
df['col1'].plot(figsize = (12,8), color='salmon')

# %%
df[['col1','col2']].plot(figsize = (12,8), style = {'col1': '--b', 'col2': '-.r'})

# %%
housing
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %% [markdown]
# ### Challenge: Create a line plot of `ZN` and `INDUS` in the housing data.

# %% [markdown]
# - For `ZN`, use a solid green line. For `INDUS`, use a blue dashed line.
# - Change the figure size to a width of 12 and height of 8.
# - Change the style sheet to something you find [here]

# %% [markdown]
# https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html

# %%
plt.style.use("bmh")
housing[["ZN", "INDUS"]].plot(figsize = (12,8), style = {"ZN": "-g", "INDUS": "--b"}, )

# %%
plt.style.use("seaborn-poster")
housing[['ZN','INDUS']].plot(figsize = (12,8), style = {'ZN':'green','INDUS':'--b'})

# %%
with plt.xkcd():
    housing[['ZN', 'INDUS']].plot(figsize=(12,8), style={'ZN': 'g','INDUS': '--b'})

# %%
plt.style.use("fivethirtyeight")

# %%
#averages of alcohol consumption by continent

# %%
drinks
# Out:
#          country  beer  spirit  wine  liters continent
# 0    Afghanistan     0       0     0     0.0        AS
# 1        Albania    89     132    54     4.9        EU
# 2        Algeria    25       0    14     0.7        AF
# 3        Andorra   245     138   312    12.4        EU
# 4         Angola   217      57    45     5.9        AF
# ..           ...   ...     ...   ...     ...       ...
# 188    Venezuela   333     100     3     7.7        SA
# 189      Vietnam   111       2     1     2.0        AS
# 190        Yemen     6       0     0     0.1        AS
# 191       Zambia    32      19     4     2.5        AF
# 192     Zimbabwe    64      18     4     4.7        AF
#
# [193 rows x 6 columns]

# %%
drinks.groupby('continent').mean()
# Out:
#                  beer      spirit        wine    liters
# continent
# AF          61.471698   16.339623   16.264151  3.007547
# AS          37.045455   60.840909    9.068182  2.170455
# EU         193.777778  132.555556  142.222222  8.617778
# OC          89.687500   58.437500   35.625000  3.381250
# SA         175.083333  114.750000   62.416667  6.308333

# %%
drinks.groupby('continent').mean().plot(kind='bar', figsize=(10,5))

# %%
drinks.groupby('continent').mean().sort_values('beer').plot(kind='bar', figsize=(12,6))

# %%
# %%time
drinks.drop('liters', axis = 1).groupby('continent').mean().plot(kind='bar')
# Out:
# Wall time: 65 ms

# %% [markdown]
# # Combine matplotlib and Pandas plotting

# %%
ax = df.plot(kind='bar', figsize=(12,6))

# Set a title
ax.set_title('This is a plot', fontsize = 20)

# xaxis labels
ax.set_xlabel('this x axis means nothing')

#yaxis lables
ax.set_ylabel('This is the y axis')

# change the location of the legend
ax.legend(loc = 2, bbox_to_anchor=(1.02, 1))

# %% [markdown]
# Location String	Location Code
# - 'best'	0
# - 'upper right'	1
# - 'upper left'	2
# - 'lower left'	3
# - 'lower right'	4
# - 'right'	5
# - 'center left'	6
# - 'center right'	7
# - 'lower center'	8
# - 'upper center'	9
# - 'center'	10

# %%
df
# Out:
#        col1      col2      col3      col4
# a  0.215444  0.881123  1.451751  1.005738
# b -0.123932 -0.305927 -0.569135  0.678836
# c  0.395304 -0.319570  0.967717 -0.671740
# d -0.159208 -0.014225 -0.556031  1.820433
# e -0.026579  0.556132 -1.459281  1.007852
# f -1.050851 -2.672460  2.110316 -1.637012
# g -0.598758 -1.250150  1.698695  0.368853
# h  0.021274  0.009200 -2.173392  0.091578
# i  0.079719  0.040432 -0.905863 -1.210862
# j -0.064501  0.178621 -1.343861 -0.600877

# %% [markdown]
# ### Challenge: Create a bar chart using `col1` and `col2`.
#
# - Give the plot a large title of your choosing.
# - Move the legend to the lower-left corner.

# %%
b1 = df[['col1','col2']].plot(kind='bar', figsize=(15,8))
b1.set_title('I miss the Bar-Graph', fontsize=30, fontweight=30)
b1.legend(loc=3)

# %%
ax = df[["col1", "col2"]].plot(kind="bar")
ax.set_title("THIS IS HANNAH'S PLOT", fontsize=50)
ax.legend(loc=3)

# %%
ax = df[["col1", "col2"]].plot(kind = "bar", stacked = True)

ax.set_title("Sweet Graph", fontsize = 30)
ax.legend(loc = 3)

# %%
df.plot(kind='barh', stacked = True)

# %% [markdown]
# # Histograms

# %%
drinks.beer.plot(kind='hist', figsize=(10,4), bins = 30)
plt.xlabel('Beer')
plt.ylabel('No of countries')
# Out:
# Text(0, 0.5, 'No of countries')

# %%
drinks
# Out:
#          country  beer  spirit  wine  liters continent
# 0    Afghanistan     0       0     0     0.0        AS
# 1        Albania    89     132    54     4.9        EU
# 2        Algeria    25       0    14     0.7        AF
# 3        Andorra   245     138   312    12.4        EU
# 4         Angola   217      57    45     5.9        AF
# ..           ...   ...     ...   ...     ...       ...
# 188    Venezuela   333     100     3     7.7        SA
# 189      Vietnam   111       2     1     2.0        AS
# 190        Yemen     6       0     0     0.1        AS
# 191       Zambia    32      19     4     2.5        AF
# 192     Zimbabwe    64      18     4     4.7        AF
#
# [193 rows x 6 columns]

# %%
drinks.beer.plot(kind='density', xlim = (0,500))

# %%
drinks.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000138BDF38F70>,
# ...
#       dtype=object)

# %%
housing['MEDV']
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %% [markdown]
# ### Challenge: Create a histogram with pandas for using `MEDV` in the housing data.
# - Set the bins to 20.

# %%
housing['MEDV'].hist(bins=20)
plt.title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
drinks.hist(column='beer',by='continent', sharex=True, sharey=True, layout = (2,3))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000138C0DEC3D0>,
# ...
#       dtype=object)

# %% [markdown]
# # Understanding outliers with box plots

# %%
drinks.describe()
# Out:
#              beer      spirit        wine      liters
# count  193.000000  193.000000  193.000000  193.000000
# mean   106.160622   80.994819   49.450777    4.717098
# std    101.143103   88.284312   79.697598    3.773298
# min      0.000000    0.000000    0.000000    0.000000
# 25%     20.000000    4.000000    1.000000    1.300000
# 50%     76.000000   56.000000    8.000000    4.200000
# 75%    188.000000  128.000000   59.000000    7.200000
# max    376.000000  438.000000  370.000000   14.400000

# %% [markdown]
# IQR = interquartile range
# IQR = Q3 - Q1
#
# Q3 + 1.5 * IQR

# %%
drinks.plot(kind='box')

# %%
housing.plot(kind='box')

# %%
drinks.boxplot(column = 'beer', by='continent')

# %% [markdown]
# # Scatterplot

# %%
drinks.plot(kind='scatter', x='beer',y='wine', color = 'crimson', s = [x**2 for x in drinks['liters']])

# %% [markdown]
# # Understanding Matplotlib Fundamentals ( Figures, subplots and axes)

# %%
fig = plt.subplots(1,1, figsize=(12,5))

# %%
x = (1,2)

# %%
fig, axes = plt.subplots(2,3)
df.plot(ax = axes[0][1])
df['col1'].plot(kind='bar', ax = axes[0][0])
drinks.beer.hist(ax = axes[0][2])

# %%
fig

# %%
housing
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
sns.pairplot(housing)

# %%
sns.heatmap(housing.corr(), annot=True)

# %%
plt.rcParams['figure.figsize'] = (14,5)
