# %%
import pandas as pd

# %%
dict1 = {'name': ['Luke','Joyce','Steve'] , 'email':['luke@skanksa','joyce@skanksa','steve@skanksa']}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#     name          email
# 0   Luke   luke@skanksa
# 1  Joyce  joyce@skanksa
# 2  Steve  steve@skanksa

# %% [markdown]
# # Reading Files

# %%
users = pd.read_csv('data/user.tbl', sep = '|')

# %%
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
type(users)
# Out:
# pandas.core.frame.DataFrame

# %%
users.head() #returns the first five rows
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
users.tail()
# Out:
#      user_id  age gender     occupation zip_code
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841

# %%
users.columns
# Out:
# Index(['user_id', 'age', 'gender', 'occupation', 'zip_code'], dtype='object')

# %%
# selecting a column method 1
users.age
# Out:
# 0      24
# 1      53
# 2      23
# 3      24
# 4      33
#        ..
# 938    26
# 939    32
# 940    20
# 941    48
# 942    22
# Name: age, Length: 943, dtype: int64

# %%
#selecting a column method 2 
users['age']
# Out:
# 0      24
# 1      53
# 2      23
# 3      24
# 4      33
#        ..
# 938    26
# 939    32
# 940    20
# 941    48
# 942    22
# Name: age, Length: 943, dtype: int64

# %%
# Number of rows and columns
users.shape
# Out:
# (943, 5)

# %%
# Datatypes for each column
users.dtypes
# Out:
# user_id        int64
# age            int64
# gender        object
# occupation    object
# zip_code      object
# dtype: object

# %%
# create a sumary of our data
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943 entries, 0 to 942
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     943 non-null    int64
#  1   age         943 non-null    int64
#  2   gender      943 non-null    object
#  3   occupation  943 non-null    object
#  4   zip_code    943 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 37.0+ KB

# %%
# Describe all numeric columns
users.describe()
# Out:
#           user_id         age
# count  943.000000  943.000000
# mean   472.000000   34.051962
# std    272.364951   12.192740
# min      1.000000    7.000000
# 25%    236.500000   25.000000
# 50%    472.000000   31.000000
# 75%    707.500000   43.000000
# max    943.000000   73.000000

# %%
users.describe(include = ['object'])
# Out:
#        gender occupation zip_code
# count     943        943      943
# unique      2         21      795
# top         M    student    55414
# freq      670        196        9

# %%
users.describe(include='all')
# Out:
#            user_id         age gender occupation zip_code
# count   943.000000  943.000000    943        943      943
# unique         NaN         NaN      2         21      795
# top            NaN         NaN      M    student    55414
# freq           NaN         NaN    670        196        9
# mean    472.000000   34.051962    NaN        NaN      NaN
# std     272.364951   12.192740    NaN        NaN      NaN
# min       1.000000    7.000000    NaN        NaN      NaN
# 25%     236.500000   25.000000    NaN        NaN      NaN
# 50%     472.000000   31.000000    NaN        NaN      NaN
# 75%     707.500000   43.000000    NaN        NaN      NaN
# max     943.000000   73.000000    NaN        NaN      NaN

# %%
average = users.age.mean()

# %%
average
# Out:
# 34.05196182396607

# %%
users.age.hist()

# %%
# Count the occurence each value
users.gender.value_counts()
# Out:
# M    670
# F    273
# Name: gender, dtype: int64

# %%
users.gender.value_counts().plot(kind='bar')

# %%
users.age.value_counts().sort_index().plot(kind='bar', figsize = (14 , 6))

# %% [markdown]
# # Excerice 1

# %%
drinks = pd.read_csv('data/drinks.csv')

# %%
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %% [markdown]
# ### 1) Print the first and last 5 rows of the data

# %%
#A:
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
drinks.tail()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 188  Venezuela            333              100              3
# 189    Vietnam            111                2              1
# 190      Yemen              6                0              0
# 191     Zambia             32               19              4
# 192   Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 188                           7.7        SA
# 189                           2.0        AS
# 190                           0.1        AS
# 191                           2.5        AF
# 192                           4.7        AF

# %% [markdown]
# ### 2) Examine the index, datatypes and shape of the drinks data

# %%
#A:
drinks.index
# Out:
# RangeIndex(start=0, stop=193, step=1)

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks.shape
# Out:
# (193, 6)

# %% [markdown]
# ### 3) Print the first 5 rows of the `beer_servings` column

# %%
#A:
drinks.beer_servings.head()
# Out:
# 0      0
# 1     89
# 2     25
# 3    245
# 4    217
# Name: beer_servings, dtype: int64

# %%
drinks[['beer_servings']]
# Out:
#      beer_servings
# 0                0
# 1               89
# 2               25
# 3              245
# 4              217
# ..             ...
# 188            333
# 189            111
# 190              6
# 191             32
# 192             64
#
# [193 rows x 1 columns]

# %% [markdown]
# ### 4) Calculate the average `beer_servings` for the entire data set

# %%
#A:
drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %% [markdown]
# ### 5) Count the number of occurrences of each 'continent' value

# %%
#A:
drinks.continent.value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: continent, dtype: int64

# %% [markdown]
# # Section 2: Filtering

# %%
# Logical Filtering : I want see users with age > 20

# %%
#users.age < 20 

users[users.age < 20]
# Out:
#      user_id  age gender occupation zip_code
# 29        30    7      M    student    55436
# 35        36   19      F    student    93117
# 51        52   18      F    student    55105
# 56        57   16      M       none    84010
# 66        67   17      M    student    60402
# ..       ...  ...    ...        ...      ...
# 871      872   19      F    student    74078
# 879      880   13      M    student    83702
# 886      887   14      F    student    27249
# 903      904   17      F    student    61073
# 924      925   18      F   salesman    49036
#
# [77 rows x 5 columns]

# %%
mask = users.age < 20

# %%
users[mask]
# Out:
#      user_id  age gender occupation zip_code
# 29        30    7      M    student    55436
# 35        36   19      F    student    93117
# 51        52   18      F    student    55105
# 56        57   16      M       none    84010
# 66        67   17      M    student    60402
# ..       ...  ...    ...        ...      ...
# 871      872   19      F    student    74078
# 879      880   13      M    student    83702
# 886      887   14      F    student    27249
# 903      904   17      F    student    61073
# 924      925   18      F   salesman    49036
#
# [77 rows x 5 columns]

# %%
under_20 = users.age < 20
users.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
students = users.occupation == 'student'

# %%
users[students]
# Out:
#      user_id  age gender occupation zip_code
# 8          9   29      M    student    01002
# 29        30    7      M    student    55436
# 31        32   28      F    student    78741
# 32        33   23      M    student    27510
# 35        36   19      F    student    93117
# ..       ...  ...    ...        ...      ...
# 927      928   21      M    student    55408
# 932      933   28      M    student    48105
# 938      939   26      F    student    33319
# 940      941   20      M    student    97229
# 942      943   22      M    student    77841
#
# [196 rows x 5 columns]

# %%
# Logical filtering with multiple conditions

# %%
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
mask = (drinks.beer_servings > 300) & (drinks.continent == 'EU')

# %%
drinks[mask]
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 45   Czech Republic            361              170            134
# 65          Germany            346              117            175
# 81          Ireland            313              118            165
# 98        Lithuania            343              244             56
# 135          Poland            343              215             56
#
#      total_litres_of_pure_alcohol continent
# 45                           11.8        EU
# 65                           11.3        EU
# 81                           11.4        EU
# 98                           12.9        EU
# 135                          10.9        EU

# %%
# OR operatior
mask = (drinks.beer_servings > 300) | (drinks.continent == 'EU')

# %%
drinks[mask]
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 1               Albania             89              132             54
# 3               Andorra            245              138            312
# 7               Armenia             21              179             11
# 9               Austria            279               75            191
# 10           Azerbaijan             21               46              5
# 15              Belarus            142              373             42
# 16              Belgium            295               84            212
# 21   Bosnia-Herzegovina             76              173              8
# 25             Bulgaria            231              252             94
# 42              Croatia            230               87            254
# 44               Cyprus            192              154            113
# 45       Czech Republic            361              170            134
# ...

# %%
mask = ((drinks.beer_servings > 300)  &  (drinks.continent == 'EU')) | (drinks.wine_servings > 200)

# %%
mask
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# Length: 193, dtype: bool

# %%
drinks[mask]
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 3              Andorra            245              138            312
# 6            Argentina            193               25            221
# 8            Australia            261               72            212
# 16             Belgium            295               84            212
# 42             Croatia            230               87            254
# 45      Czech Republic            361              170            134
# 48             Denmark            224               81            278
# 55   Equatorial Guinea             92                0            233
# 61              France            127              151            370
# 65             Germany            346              117            175
# 67              Greece            133              112            218
# 81             Ireland            313              118            165
# ...

# %%
drinks[drinks.continent.isin(['EU','SA'])]
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 1               Albania             89              132             54
# 3               Andorra            245              138            312
# 6             Argentina            193               25            221
# 7               Armenia             21              179             11
# 9               Austria            279               75            191
# 10           Azerbaijan             21               46              5
# 15              Belarus            142              373             42
# 16              Belgium            295               84            212
# 20              Bolivia            167               41              8
# 21   Bosnia-Herzegovina             76              173              8
# 23               Brazil            245              145             16
# 25             Bulgaria            231              252             94
# ...

# %%
users.sort_values('age') #sort by a single column
# Out:
#      user_id  age gender     occupation zip_code
# 29        30    7      M        student    55436
# 470      471   10      M        student    77459
# 288      289   11      M           none    94619
# 879      880   13      M        student    83702
# 608      609   13      F        student    55106
# ..       ...  ...    ...            ...      ...
# 584      585   69      M      librarian    98501
# 766      767   70      M       engineer    00000
# 802      803   70      M  administrator    78212
# 859      860   70      F        retired    48322
# 480      481   73      M        retired    37771
#
# [943 rows x 5 columns]

# %%
users.sort_values('age', ascending = False)
# Out:
#      user_id  age gender     occupation zip_code
# 480      481   73      M        retired    37771
# 802      803   70      M  administrator    78212
# 766      767   70      M       engineer    00000
# 859      860   70      F        retired    48322
# 584      585   69      M      librarian    98501
# ..       ...  ...    ...            ...      ...
# 879      880   13      M        student    83702
# 608      609   13      F        student    55106
# 288      289   11      M           none    94619
# 470      471   10      M        student    77459
# 29        30    7      M        student    55436
#
# [943 rows x 5 columns]

# %%
users.sort_values(['occupation','age'] , ascending = [True, False])
# Out:
#      user_id  age gender     occupation zip_code
# 802      803   70      M  administrator    78212
# 265      266   62      F  administrator    78756
# 130      131   59      F  administrator    15237
# 818      819   59      M  administrator    40205
# 6          7   57      M  administrator    91344
# ..       ...  ...    ...            ...      ...
# 800      801   22      M         writer    92154
# 49        50   21      M         writer    52245
# 444      445   21      M         writer    92653
# 506      507   18      F         writer    28450
# 619      620   18      F         writer    81648
#
# [943 rows x 5 columns]

# %%
users.sort_values(['occupation','age'] , ascending = [True, False], inplace = True)

# %%
users
# Out:
#      user_id  age gender     occupation zip_code
# 802      803   70      M  administrator    78212
# 265      266   62      F  administrator    78756
# 130      131   59      F  administrator    15237
# 818      819   59      M  administrator    40205
# 6          7   57      M  administrator    91344
# ..       ...  ...    ...            ...      ...
# 800      801   22      M         writer    92154
# 49        50   21      M         writer    52245
# 444      445   21      M         writer    92653
# 506      507   18      F         writer    28450
# 619      620   18      F         writer    81648
#
# [943 rows x 5 columns]

# %%
users = users.sort_values(['occupation','age'] , ascending = [True, False])

# %%
users
# Out:
#      user_id  age gender     occupation zip_code
# 802      803   70      M  administrator    78212
# 265      266   62      F  administrator    78756
# 130      131   59      F  administrator    15237
# 818      819   59      M  administrator    40205
# 6          7   57      M  administrator    91344
# ..       ...  ...    ...            ...      ...
# 800      801   22      M         writer    92154
# 49        50   21      M         writer    52245
# 444      445   21      M         writer    92653
# 506      507   18      F         writer    28450
# 619      620   18      F         writer    81648
#
# [943 rows x 5 columns]

# %% [markdown]
# USE THE DRINKS DATASET

# %% [markdown]
# ### 1) Filter the DataFrame to only include European countries

# %%
#A:
in_europe = drinks.continent == 'EU'
drinks[in_europe]
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 1               Albania             89              132             54
# 3               Andorra            245              138            312
# 7               Armenia             21              179             11
# 9               Austria            279               75            191
# 10           Azerbaijan             21               46              5
# 15              Belarus            142              373             42
# 16              Belgium            295               84            212
# 21   Bosnia-Herzegovina             76              173              8
# 25             Bulgaria            231              252             94
# 42              Croatia            230               87            254
# 44               Cyprus            192              154            113
# 45       Czech Republic            361              170            134
# ...

# %% [markdown]
# ### 2) Filter the DataFrame to only include European countries with wine_servings > 300

# %%
#A:
eu_wine_over_300 = (drinks.continent == 'EU') & (drinks.wine_servings > 300)
drinks[eu_wine_over_300]
# Out:
#       country  beer_servings  spirit_servings  wine_servings  \
# 3     Andorra            245              138            312
# 61     France            127              151            370
# 136  Portugal            194               67            339
#
#      total_litres_of_pure_alcohol continent
# 3                            12.4        EU
# 61                           11.8        EU
# 136                          11.0        EU

# %% [markdown]
# ### 3) Calculate the average `beer_servings` for all of Europe

# %%
#A:
drinks[in_europe].beer_servings.mean()
# Out:
# 193.77777777777777

# %% [markdown]
# ### 4) Determine which 10 countries have the highest `total_litres_of_pure_alcohol`.
# Hint: The head method takes a integer as an input to determine the number of rows to return

# %%
drinks.sort_values('total_litres_of_pure_alcohol', ascending =False).head(10).describe(include = 'all')
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# count         10      10.000000        10.000000      10.000000
# unique        10            NaN              NaN            NaN
# top     Slovakia            NaN              NaN            NaN
# freq           1            NaN              NaN            NaN
# mean         NaN     240.900000       238.400000     156.700000
# std          NaN      79.338165       113.845119     121.007851
# min          NaN     127.000000       118.000000      28.000000
# 25%          NaN     196.750000       141.250000      60.250000
# 50%          NaN     240.500000       207.000000     125.000000
# 75%          NaN     296.500000       317.750000     244.500000
# max          NaN     361.000000       438.000000     370.000000
#
#         total_litres_of_pure_alcohol continent
# count                      10.000000         9
# unique                           NaN         2
# top                              NaN        EU
# ...
